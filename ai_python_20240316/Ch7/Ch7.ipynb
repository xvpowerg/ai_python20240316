# %%
priceList=[]
priceSum = 0
for i in range(1,5):
    p = int(input(f"請輸入{i}個月的支出金額"))
    priceSum =priceSum + p
    priceList.append(p)
priceList.sort()
print(f"max:{priceList[len(priceList)-1]}") 
print(f"min:{priceList[0]}")
print(priceSum)    
print(priceList) 

print(sum(priceList)) 
print(max(priceList))    
print(min(priceList))
# Out:
# 請輸入1個月的支出金額 1000
# 請輸入2個月的支出金額 3000
# 請輸入3個月的支出金額 6000
# 請輸入4個月的支出金額 4000
# max:6000
# min:1000
# 14000
# [1000, 3000, 4000, 6000]
# 14000
# 6000
# 1000

# %%
num1 = 10
num2 = 0
try:
    print(num1 / num2)
except ZeroDivisionError:
    print("有問題發生!:","ZeroDivisionError")
print("Test!!")
# Out:
# 有問題發生!: ZeroDivisionError
# Test!!

# %%
myList = [1,2,3]
try:
    while True:
        print(myList.pop())
except:    
    pass
# Out:
# 3
# 2
# 1

# %%
def testScore(score:int):
    if score < 0 or score > 100:
        print("錯誤的成績")
        return
    print("score:",score)    
    #score是0~100顯示成績
    #不在範圍內 錯誤的成績
print("Test1")
testScore(-1)
print("Test2")
# Out:
# Test1
# 錯誤的成績
# Test2

# %% [markdown]
# ## 使用raise拋例外

# %%
def testScore(score:int):
    if score < 0 or score > 100:
        raise OverflowError("錯誤的成績")
    print("score:",score)  
print("Test1")
testScore(-1)
print("Test2")
# Out:
# Test1
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[33], line 6
#       4     print("score:",score)
#       5 print("Test1")
# ----> 6 testScore(-1)
#       7 print("Test2")
#
# Cell In[33], line 3, in testScore(score)
#       1 def testScore(score:int):
#       2     if score < 0 or score > 100:
# ----> 3         raise OverflowError("錯誤的成績")
#       4     print("score:",score)
#
# OverflowError: 錯誤的成績

# %%
n1 = 10
n2 = 0
myList = [1,2,3] 
try:
    #n1/n2
    #myList[10]
    myListx.pop()
except ZeroDivisionError as ex:
    print("ZeroDivisionError:",ex)
except IndexError as ex:
    print("IndexError:",ex)
except Exception as ex:#除了以上以外的錯誤
     print("Exception:",ex)
# Out:
# Exception: name 'myListx' is not defined

# %% [markdown]
# ## 正規表示式
# ![image.png](attachment:a2076929-49d8-4e34-9e67-bc3a5dd5d929.png)
# ![image.png](attachment:ba521394-fda6-4f20-9c88-4e3333d2610c.png)

# %%
import re
s = "Tim's phone numbers are 12345-41521 and 78963-85214"
match = re.findall(r"\d",s)
print(match)
# Out:
# ['1', '2', '3', '4', '5', '4', '1', '5', '2', '1', '7', '8', '9', '6', '3', '8', '5', '2', '1', '4']

# %% [markdown]
# ![image.png](attachment:732f9b13-b77f-42dd-bfd9-37d6f6d65c2e.png)

# %%
import re
s = "Tim's phone numbers are 12345-41521 and 78963-85214"
match = re.findall(r"\d{5}",s)
print(match)
# Out:
# ['12345', '41521', '78963', '85214']

# %% [markdown]
# ![image.png](attachment:08fc71d3-0b7c-4c70-8316-4a22653f4b09.png)

# %%
import  re
s="Python was conceiaaaaaaaaaaaaaaaaaaaved in the late 1980s by Guido van Rossum"
#match = re.findall(r"[a-t]",s)
#match = re.findall(r"[a-t]{2}",s)
#match = re.findall(r"[a-t]{3,6}",s)
match = re.findall(r"[a-t]{4,}",s)
print(match)
# Out:
# ['thon', 'conceiaaaaaaaaaaaaaaaaaaa', 'late']

# %% [markdown]
# ![image.png](attachment:7f3469ba-9420-4327-a107-98b614379cb3.png)

# %%
import  re
pattern = re.compile(r"\d+")
r1 = pattern.findall("hello 123456 789")
r2 = pattern.findall("hello 15623 995 9877")
print(r1)
print(r2)
# Out:
# ['234567', '123456', '789']
# ['15623', '995', '9877']

# %%
import re
str1="abc1d abcdd abc2b abc aaaa"
print(re.findall(r"abcd?",str1))
print(re.findall(r"abcd*",str1))
print(re.findall(r"abcd+",str1))
# Out:
# ['abc', 'abcd', 'abc', 'abc']
# ['abc', 'abcdd', 'abc', 'abc']
# ['abcdd']

# %% [markdown]
# ## split 方法
# + split 方法能以比對規則針對字串進行切割後產生 list。
# + split 它的使用形式如下：
# + split(字串,最大分割次數)
#    + 若不指定最大分割次數則全部分割

# %%
import re
text = 'one1two2ten'
v1 = re.split(r"\d",text)
print(v1)
print(v1[0])
v2 = re.split(r"\d",text,1)
print(v2)

text = 'one,two,ten'
v1 = re.split(r",",text)
print(v1)
print(v1[0])
v2 = re.split(r",",text,1)
print(v2)
# Out:
# ['one', 'two', 'ten']
# one
# ['one', 'two2ten']
# ['one', 'two', 'ten']
# one
# ['one', 'two,ten']

# %% [markdown]
# ## sub 方法
# + sub 方法用於替換，它的使用形式如下
#   + sub(取代的字串或函數,來源字串,可設定被取代的數量)
# + 可設定被取代的數量若不指定時全部替換。

# %%
import re
inputStr = "This is Python.That is Java,This is SQLite"
nStr = inputStr.replace("is","-")
print(nStr)
# Out:
# Th- - Python.That - Java,Th- - SQLite

# %%
import re
inputStr = "This is Python.That is Java,This is SQLite"
#\b空白無字的
nStr = re.sub(r"\bis\b","-",inputStr)
print(nStr)
# Out:
# This - Python.That - Java,This - SQLite

# %% [markdown]
# ## 作業
#
# 設計錢包總金額為 1000 元，
#
# 如果購買商品總金額超過 1000
#
# 會引發一個金額不足的例外 OverflowError
# ![image.png](attachment:c93ec062-0869-4025-95fd-ac022b77a82d.png)

# %% [markdown]
# ## 物件導向入門

# %%
class Employee:
    pass
emp = Employee()#建立物件
print(type(emp))
emp.name = "Ken"#建立屬性
emp.salary = 50000
print(emp.name,emp.salary)
emp2 = Employee()
print(emp2.name)
# Out:
# <class '__main__.Employee'>
# Ken 50000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 9
#       7 print(self.name,self.salary)
#       8 emp2 = Employee()
# ----> 9 print(emp2.name)
#
# AttributeError: 'Employee' object has no attribute 'name'

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
emp1 = Employee("Ken",25000)
print(emp1.name)
print(emp1.salary)
# Out:
# Ken
# 25000

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    def printInfo(self):
        print("name:",self.name,"salary:",self.salary)
emp1 = Employee("Ken",25000)
emp1.printInfo()
emp2 = Employee("Vivin",65000)
emp2.printInfo()
# Out:
# name: Ken salary: 25000
# name: Vivin salary: 65000

# %% [markdown]
# ## 繼承

# %%
class Animal:
    def __init__(self,name,age=0):
        self.name = name
        self.age = age
    def printInfo(self):
        print("資訊:",self.name,self.age)
an1 = Animal("Bobo")
an1.printInfo()
an2 = Animal("Lulu",2)
an2.printInfo()
# Out:
# 資訊: Bobo 0
# 資訊: Lulu 2

# %%
class Cat(Animal):
    def printInfo(self):
        print("C:",self.name,self.age)
cat1 = Cat("Kitty",3)
cat1.printInfo()
# Out:
# C: Kitty 3

# %%
class Dog(Animal):
   def printInfo(self):
        print("D:",end="")
        # super()呼叫父類別的東西
        super().printInfo()
   
dog1 = Dog("Kiki",2)
dog1.printInfo()
# Out:
# D:資訊: Kiki 2

# %% [markdown]
# ## 多重繼承與初始化方法
# ### 多重繼承
# + 繼承多個父類別時用，隔開
# + 注意成員搜尋的順序
#   + 從子類別開始
#   + 同一階層父類別由左至右搜尋
#   + 更上層祖父類別由左至右搜尋
#   + 直到達到頂層為止

# %%
class S:
    def method1(self):
        print("S method1")
    def method2(self):
        print("S method2")   
class A(S):
    def method3(self):
        print("A method3")
class B(S):
    def method2(self):
        print("B method2")
    def method3(self):
        print("B method3")
class C(A,B):
    def method4(self):
        print("C method4")
c = C()  
c.method4()
c.method3()
c.method2()
c.method1()
# Out:
# C method4
# A method3
# B method2
# S method1

# %% [markdown]
# ## __str__ 可輸出物件的內容

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
# Out:
# (2,3)
# (-1,2)

# %% [markdown]
# ``` python
# __add__  +
#
# __iadd__  +=
#
# __sub__  -
#
# __isub__  -=
#
# __mul__  *
#
# __imul__  *=
#
# __truediv__   /
#
# __itruediv__   /=
#
# __floordiv__  //
#
# __ifloordiv__  //=
#
# __mod__  %
#
# __imod__  %=
#
# __pow__  **
#
# __ipow__  **=
# ```

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __len__(self):
        myLen =  (self.x ** 2) + (self.y ** 2)
        return myLen
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
p3 = p1 + p2
print(p3)
print(len(p1))
# Out:
# (2,3)
# (-1,2)
# (1,5)
# 13

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __len__(self):
        myLen =  (self.x ** 2) + (self.y ** 2)
        return myLen
    def __lt__(self,other):
        selfLen = len(self)
        otheLen = len(other)
        return selfLen < otheLen
p1 = Point(2,3)
p2 = Point(-1,2)
p3 = Point(9,11)
p4 = Point(7,12)
print(p1 < p2)
print(p1 > p2)
pointList = [p1,p2,p3,p4]
pointList.sort()
for p in pointList:
    print(p)
# Out:
# False
# True
# (-1,2)
# (2,3)
# (7,12)
# (9,11)

# %% [markdown]
# ## 目錄管理

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\xvpow\ai_python_20240316\Ch7

# %%
import os
# 切換路徑
#os.chdir(r"C:\Users\xvpow\ai_python_20240316\Ch7")
print(os.getcwd())
myDir = os.listdir()
for f in myDir:
    print(f)
# Out:
# C:\Users\xvpow\ai_python_20240316\Ch7
# .ipynb_checkpoints
# Ch7.ipynb

# %%
from os import listdir
from os.path import isfile,isdir
files = listdir()
print(files)
for f in files:
    if isfile(f):
        print("檔案:",f)
    elif isdir(f):
         print("目錄:",f)
# Out:
# ['.ipynb_checkpoints', 'Ch7.ipynb', 'Dir1', 'Dir2']
# 目錄: .ipynb_checkpoints
# 檔案: Ch7.ipynb
# 目錄: Dir1
# 目錄: Dir2

# %%
from os import walk
import os
print(os.getcwd())
mypath = "."
for root,dirs,files in walk(mypath):
    print("路徑:",root)
    print("  目錄:",dirs)
    print("  檔案:",files)
# Out:
# C:\Users\xvpow\ai_python_20240316\Ch7
# 路徑: .
#   目錄: ['.ipynb_checkpoints', 'Dir1', 'Dir2']
#   檔案: ['Ch7.ipynb']
# 路徑: .\.ipynb_checkpoints
#   目錄: []
#   檔案: ['Ch7-checkpoint.ipynb']
# 路徑: .\Dir1
#   目錄: []
#   檔案: ['Test1.txt', 'Test2.txt']
# 路徑: .\Dir2
#   目錄: ['Dir2_1']
#   檔案: ['Test2.txt']
# 路徑: .\Dir2\Dir2_1
#   目錄: []
#   檔案: []
